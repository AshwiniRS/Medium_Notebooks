# %% [markdown]
# <h1> WordCloud of tweets hashtags on blockchain topic </h1>

# %% [markdown]
# <b>In this notebook, we will go through following things-<br></b>
# <li> 1. Installing required packages</li>
# <li> 2. Collecting tweets through twitter API</li>
# <li> 3. Cleaning the tweets </li>
# <li> 4. Counting frequencies of hashtags </li>
# <li> 5. Wordcloud </li>

# %% [markdown]
# <h3>Installing required packages using cran repository.</h3>

# %%
install.packages("twitteR", repos='http://cran.us.r-project.org')
install.packages("wordcloud", repos='http://cran.us.r-project.org')
install.packages("tm", repos='http://cran.us.r-project.org')
install.packages("devtools", repos='http://cran.us.r-project.org')
install.packages("stringr", repos='http://cran.us.r-project.org')

# %% [markdown]
# <h3>Import the required packages</h3>

# %%
library(twitteR) #for twitter API
library(wordcloud) #to plot wordcloud
library(RColorBrewer) #for colors in wordcloud
library(tm) #required for some functions
library(stringr) #required for some functions
# Out:
# Loading required package: RColorBrewer
# Loading required package: NLP

# %% [markdown]
# Collecting tweets through twitter API

# %%
consumer_key <- ""
consumer_secret <- ""
access_token <- ""
access_secret <- ""
setup_twitter_oauth(consumer_key, consumer_secret, access_token, access_secret)
tweets = searchTwitter("#blockchain",n=5000)
cat("Authentication successful.")
# Out:
# [1] "Using direct authentication"
# Authentication successful.

# %% [markdown]
# <h3>Looking into the tweets!</h3>

# %%
head(tweets,10)
# Out:
# [[1]]
# [1] "HendraKholis: RT @domraider: Vote for @domraider #blockchain project at #ICO Pitch Contest @d10e_conference Fingers crossed<ed><U+00A0><U+00BE><ed><U+00B4><U+009E> <U+27A1><U+FE0F> https://t.co/UHrZEJlS5F h"
#
# [[2]]
# [1] "DelFlon1: RT @TheStigTaxi: Have an Amazing <U+261E> #Dash\n#Blackcab at your Service <U+261B> .@anthemhayek \n.@AnthemGold #blockchain #digitalCash #crypto\nhttps://t"
#
# [[3]]
# [1] "DopeSoufRadio: RT @WestsideSEO: Developing &amp; supporting #Big Data application #AI #BlockChain #DataScience #IoT #defstar5 #Mpgvip #Tech #BigData  https://"
#
# [[4]]
# [1] "ADORNti: RT @DeepLearn007: #Fintech Will be a Culmination of #Blockchain , Artificial intelligence &amp; #MachineLearning \n#AI #ML #Iot #tech \nhttps://t"
#
# [[5]]
# [1] "itknowingness: RT @mclynd: #Fintech Will be a Culmination of #Blockchain , #ArtificialIntelligence &amp; #MachineLearning \n#AI #Iot https://t.co/ZXwOxkiTFk @"
#
# [[6]]
# [1] "mclynd: #Fintech Will be a Culmination of #Blockchain , #ArtificialIntelligence &amp; #MachineLearning \n#AI #Iot https://t.co/eLSvBzquiy"
#
# [[7]]
# [1] "DXCworkplace: RT @ipfconline1: What Can You Do With #Blockchain\nby @DeloitteUK\n#Fintech #Bitcoin #Etherum #Crowdfunding #IoT #IIoT #Infosec #Suplychain\nH"
#
# [[8]]
# [1] "blockchainhelpr: What is An Initial Coin Offering? The Future of Fundraising \n https://t.co/tKtJUwuUv8 #Blockchain #Ethereum https://t.co/zlgyhU89cr"
#
# [[9]]
# [1] "Curtis_Clark_28: The latest The Government innovation, digital Gov Daily! https://t.co/21zRsH5Rjl #blockchain"
#
# [[10]]
# [1] "suicidalbanker: https://t.co/0ScptZxYqG \"Me now that I'm trading in four different currencies\" #Bitcoin #Ethereum #Blockchain #Trading"

# %% [markdown]
# <h3>Save tweets in Rdata file</h3>

# %%
save(tweets, file = "tweets.Rdata")

# %%
load("tweets.Rdata")
tweetsList <- tweets

# %% [markdown]
# Converting the tweetsList to data frame

# %%
tweetsFrame <- twListToDF(tweetsList)

# %%
head(tweetsFrame,10)
# Out:
#    text
# 1  RT @domraider: Vote for @domraider #blockchain project at #ICO Pitch Contest @d10e_conference Fingers crossed<ed><U+00A0><U+00BE><ed><U+00B4><U+009E> <U+27A1><U+FE0F> https://t.co/UHrZEJlS5F h
# 2  RT @TheStigTaxi: Have an Amazing <U+261E> #Dash\n#Blackcab at your Service <U+261B> .@anthemhayek \n.@AnthemGold #blockchain #digitalCash #crypto\nhttps://t
# 3  RT @WestsideSEO: Developing &amp; supporting #Big Data application #AI #BlockChain #DataScience #IoT #defstar5 #Mpgvip #Tech #BigData  https://
# 4  RT @DeepLearn007: #Fintech Will be a Culmination of #Blockchain , Artificial intelligence &amp; #MachineLearning \n#AI #ML #Iot #tech \nhttps://t
# 5  RT @mclynd: #Fintech Will be a Culmination of #Blockchain , #ArtificialIntelligence &amp; #MachineLearning \n#AI #Iot https://t.co/ZXwOxkiTFk @
# 6  #Fintech Will be a Culmination of #Blockchain , #ArtificialIntelligence &amp; #MachineLearning \n#AI #Iot https://t.co/eLSvBzquiy
# 7  RT @ipfconline1: What Can You Do With #Blockchain\nby @DeloitteUK\n#Fintech #Bitcoin #Etherum #Crowdfunding #IoT #IIoT #Infosec #Suplychain\nH
# 8  What is An Initial Coin Offering? The Future of Fundraising \n https://t.co/tKtJUwuUv8 #Blockchain #Ethereum https://t.co/zlgyhU89cr
# 9  The latest The Government innovation, digital Gov Daily! https://t.co/21zRsH5Rjl #blockchain
# 10 https://t.co/0ScptZxYqG "Me now that I'm trading in four different currencies" #Bitcoin #Ethereum #Blockchain #Trading
#    favorited favoriteCount replyToSN created             truncated replyToSID
# 1  FALSE     0             NA        2017-09-25 00:29:40 FALSE     NA
# 2  FALSE     0             NA        2017-09-25 00:29:36 FALSE     NA
# 3  FALSE     0             NA        2017-09-25 00:29:30 FALSE     NA
# 4  FALSE     0             NA        2017-09-25 00:29:27 FALSE     NA
# 5  FALSE     0             NA        2017-09-25 00:29:22 FALSE     NA
# 6  FALSE     0             NA        2017-09-25 00:29:21  TRUE     NA
# 7  FALSE     0             NA        2017-09-25 00:29:21 FALSE     NA
# 8  FALSE     0             NA        2017-09-25 00:29:20 FALSE     NA
# 9  FALSE     0             NA        2017-09-25 00:29:18 FALSE     NA
# 10 FALSE     0             NA        2017-09-25 00:29:17 FALSE     NA
#    id                 replyToUID
# 1  912111826975940608 NA
# 2  912111809703837696 NA
# 3  912111783460134913 NA
# 4  912111773150531584 NA
# 5  912111751025569792 NA
# 6  912111749343645696 NA
# 7  912111745958907904 NA
# 8  912111744398643200 NA
# 9  912111734814576641 NA
# 10 912111731899584513 NA
#    statusSource
# 1  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://dopesouf.com" rel="nofollow">dopesoufradio</a>
# 4  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 5  <a href="http://www.itknowingness.com" rel="nofollow">ttools it knowingness</a>
# 6  <a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>
# 7  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 8  <a href="https://www.socialoomph.com" rel="nofollow">SocialOomph</a>
# 9  <a href="http://paper.li" rel="nofollow">Paper.li</a>
# 10 <a href="https://ifttt.com" rel="nofollow">IFTTT</a>
#    screenName      retweetCount isRetweet retweeted longitude latitude
# 1  HendraKholis    124           TRUE     FALSE     NA        NA
# 2  DelFlon1         27           TRUE     FALSE     NA        NA
# 3  DopeSoufRadio     5           TRUE     FALSE     NA        NA
# 4  ADORNti          84           TRUE     FALSE     NA        NA
# 5  itknowingness     1           TRUE     FALSE     NA        NA
# 6  mclynd            1          FALSE     FALSE     NA        NA
# 7  DXCworkplace    100           TRUE     FALSE     NA        NA
# 8  blockchainhelpr   0          FALSE     FALSE     NA        NA
# 9  Curtis_Clark_28   0          FALSE     FALSE     NA        NA
# 10 suicidalbanker    0          FALSE     FALSE     NA        NA

# %% [markdown]
# <h3>Cleaning the tweets</h3>

# %%
tweetsFrame$text <- sapply(tweetsFrame$text,function(row) iconv(row, "latin1", "ASCII", sub=""))

# %%
clean.text <- function(text){
    text = gsub("&amp", "", text)
    #text = gsub("[[:punct:]]", "", text) #to remove punctuations and other symbols
    text = gsub("[[:digit:]]", "", text) #to remove digits
    text = gsub("https:\\w+", "", text) #to remove urls
    text = gsub("[ t]{2,}", "", text) #to remove tabs
    text = gsub("^\\s+|\\s+$", "", text) #to remove extra spaces
    return(text)
}

# %%
tweetsFrame$text = removeWords(tweetsFrame$text, stopwords("english"))

# %%
tweetsFrame$text <- clean.text(tweetsFrame$text)

# %%
head(tweetsFrame,10)
# Out:
#    text
# 1  RT @domraider: Vote@domraider #blockchain projec#ICO Pitch Contes@de_conference Fingers crossedhps://t.co/UHrZEJlSF h
# 2  RT @TheStigTaxi: HaveAmazing#Dash\n#BlackcabService.@anthemhayek \n.@AnthemGold #blockchain #digitalCash #crypto\nhps://t
# 3  RT @WestsideSEO: Developing ; supporting #Big Data application #AI #BlockChain #DataScience #IoT #defstar #Mpgvip #Tech #BigDatahps://
# 4  RT @DeepLearn: #Fintech WillCulmination#Blockchain , Artificial intelligence ; #MachineLearning \n#AI #ML #Io#tech \nhps://t
# 5  RT @mclynd: #Fintech WillCulmination#Blockchain , #ArtificialIntelligence ; #MachineLearning \n#AI #Iohps://t.co/ZXwOxkiTFk @
# 6  #Fintech WillCulmination#Blockchain , #ArtificialIntelligence ; #MachineLearning \n#AI #Iohps://t.co/eLSvBzquiy
# 7  RT @ipfconline: WhaCan You Do With #Blockchain\n @DeloieUK\n#Fintech #Bitcoin #Etherum #Crowdfunding #IoT #IIoT #Infosec #Suplychain\nH
# 8  WhaAn Initial Coin Offering? The FutureFundraising \n hps://t.co/tKtJUwuUv #Blockchain #Ethereum hps://t.co/zlgyhUcr
# 9  The latesThe Governmeninnovation, digital Gov Daily! hps://t.co/zRsHRjl #blockchain
# 10 hps://t.co/ScptZxYqG "Me nowI'mradingfour differencurrencies" #Bitcoin #Ethereum #Blockchain #Trading
#    favorited favoriteCount replyToSN created             truncated replyToSID
# 1  FALSE     0             NA        2017-09-25 00:29:40 FALSE     NA
# 2  FALSE     0             NA        2017-09-25 00:29:36 FALSE     NA
# 3  FALSE     0             NA        2017-09-25 00:29:30 FALSE     NA
# 4  FALSE     0             NA        2017-09-25 00:29:27 FALSE     NA
# 5  FALSE     0             NA        2017-09-25 00:29:22 FALSE     NA
# 6  FALSE     0             NA        2017-09-25 00:29:21  TRUE     NA
# 7  FALSE     0             NA        2017-09-25 00:29:21 FALSE     NA
# 8  FALSE     0             NA        2017-09-25 00:29:20 FALSE     NA
# 9  FALSE     0             NA        2017-09-25 00:29:18 FALSE     NA
# 10 FALSE     0             NA        2017-09-25 00:29:17 FALSE     NA
#    id                 replyToUID
# 1  912111826975940608 NA
# 2  912111809703837696 NA
# 3  912111783460134913 NA
# 4  912111773150531584 NA
# 5  912111751025569792 NA
# 6  912111749343645696 NA
# 7  912111745958907904 NA
# 8  912111744398643200 NA
# 9  912111734814576641 NA
# 10 912111731899584513 NA
#    statusSource
# 1  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://dopesouf.com" rel="nofollow">dopesoufradio</a>
# 4  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 5  <a href="http://www.itknowingness.com" rel="nofollow">ttools it knowingness</a>
# 6  <a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>
# 7  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 8  <a href="https://www.socialoomph.com" rel="nofollow">SocialOomph</a>
# 9  <a href="http://paper.li" rel="nofollow">Paper.li</a>
# 10 <a href="https://ifttt.com" rel="nofollow">IFTTT</a>
#    screenName      retweetCount isRetweet retweeted longitude latitude
# 1  HendraKholis    124           TRUE     FALSE     NA        NA
# 2  DelFlon1         27           TRUE     FALSE     NA        NA
# 3  DopeSoufRadio     5           TRUE     FALSE     NA        NA
# 4  ADORNti          84           TRUE     FALSE     NA        NA
# 5  itknowingness     1           TRUE     FALSE     NA        NA
# 6  mclynd            1          FALSE     FALSE     NA        NA
# 7  DXCworkplace    100           TRUE     FALSE     NA        NA
# 8  blockchainhelpr   0          FALSE     FALSE     NA        NA
# 9  Curtis_Clark_28   0          FALSE     FALSE     NA        NA
# 10 suicidalbanker    0          FALSE     FALSE     NA        NA

# %% [markdown]
# <h3>Extracting hashtags</h3>

# %% [markdown]
# Extracting hashtags and counting its frequencies.

# %%
result_df <- data.frame(table(unlist(str_extract_all(tweetsFrame$text,"#[a-zA-Z0-9]{2,}"))))

# %%
head(result_df,10)
# Out:
#    Var1         Freq
# 1  #accelerator 1
# 2  #accounting  1
# 3  #actnow      2
# 4  #ad          1
# 5  #ADCOM       1
# 6  #Adopcin     1
# 7  #Ads         8
# 8  #adventure   1
# 9  #Advertising 5
# 10 #Africa      1

# %% [markdown]
# <h3>Arranging hashtags in descending order of their frequencies.</h3>

# %%
result_df <- result_df[rev(order(result_df$Freq)),]
head(result_df)
result_df = na.omit(result_df)
# Out:
#     Var1            Freq
# 171 #blockchain     2627
# 172 #Blockchain     1667
# 16  #AI              845
# 400 #cryptocurrency  833
# 664 #fintech         670
# 139 #bitcoin         653

# %%
result_df_temp=result_df[2:200,]
head(result_df_temp,10)
# Out:
#     Var1            Freq
# 172 #Blockchain     1667
# 16  #AI              845
# 400 #cryptocurrency  833
# 664 #fintech         670
# 139 #bitcoin         653
# 889 #IoT             603
# 792 #ICO             522
# 619 #ethereum        472
# 140 #Bitcoin         463
# 666 #Fintech         411

# %% [markdown]
# <h3>Wordcloud of top 200 hashtags</h3>

# %%
wordcloud(result_df_temp$Var1, result_df_temp$Freq, random.order=FALSE,colors=brewer.pal(8, "Dark2"))
# Out:
# plot without title
